# %%
import warnings
warnings.filterwarnings('ignore')

import os
from os import listdir
import pathlib
from random import randint
import numpy as np
from numpy import asarray
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
import tensorflow_addons as tfa
from keras.utils import load_img,img_to_array
from keras.models import Sequential
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras.layers import MaxPooling2D,Dropout,Dense,Input,Conv2D,Flatten,Conv2DTranspose
from keras.layers import GlobalAveragePooling2D,MaxPool2D,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.utils import plot_model

# %%
folder = '/kaggle/input/alzheimer-mri-dataset/Dataset'
folder_path = pathlib.Path(folder)

# %%
photo = load_img('/kaggle/input/alzheimer-mri-dataset/Dataset/Mild_Demented/mild.jpg')
print(photo)
photo
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x70E89329ED50>
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
for file in listdir(folder):
    print(file)
# Out:
# Non_Demented
# Mild_Demented
# Moderate_Demented
# Very_Mild_Demented

# %%
plt.figure(figsize=(7,7),)
j =0
for file in listdir(folder):
    i =0
    for image in listdir(folder + '/'+file):
        if i ==1:
            break;
        img = imread(folder +'/' + file + '/' + image)
        ax = plt.subplot(2,2,j+1)
        plt.imshow(img)
        plt.title(image)
        plt.axis('off')
        j = j+1
        i = i +1
plt.show()

# %%
# counting the number of images in each category
for file in listdir(folder):
    i =0
    for image in listdir(folder + '/'+file):
        i = i +1
    print(file , i)
# Out:
# Non_Demented 3200
# Mild_Demented 896
# Moderate_Demented 64
# Very_Mild_Demented 2240

# %% [markdown]
# #### Here we can see that the dataset is completely imbalanced with different number of images in each category

# %%
# Creating the image datagenerator to have more samples
IMG_SIZE = 128
DIM = (IMG_SIZE, IMG_SIZE)

ZOOM = [.99, 1.01]
BRIGHT_RANGE = [0.8, 1.2]
HORZ_FLIP = True
FILL_MODE = "constant"
DATA_FORMAT = "channels_last"

# %%
train_generator = ImageDataGenerator(rescale = 1./255, brightness_range=BRIGHT_RANGE, zoom_range=ZOOM, 
                                     data_format=DATA_FORMAT, fill_mode=FILL_MODE, horizontal_flip=HORZ_FLIP)
train_data_gen = train_generator.flow_from_directory(directory=folder, target_size=DIM, batch_size=6500, shuffle=False)
# Out:
# Found 6400 images belonging to 4 classes.

# %%
CLASSES = list(train_data_gen.class_indices.keys())

def show_images(generator,y_pred=None):
    # get image lables
    labels =dict(zip([0,1,2,3], CLASSES))
    
    # get a batch of images
    x,y = generator.next()
    
    # display a grid of 9 images
    plt.figure(figsize=(7, 7))
    if y_pred is None:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            idx = randint(0, 6400)
            plt.imshow(x[idx])
            plt.axis("off")
            plt.title("Class:{}".format(labels[np.argmax(y[idx])]))                                                    
    else:
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(x[i])
            plt.axis("off")
            plt.title("Actual:{} \nPredicted:{}".format(labels[np.argmax(y[i])],labels[y_pred[i]]))
    
# Display Train Images
show_images(train_data_gen)

# %%
train_data, train_labels = train_data_gen.next()

# %%
train_data.shape, train_labels.shape
# Out:
# ((6400, 128, 128, 3), (6400, 4))

# %% [markdown]
# Since the data in each class is imbalanced we need to oversample the data

# %%
sm = SMOTE(random_state=42)

train_data, train_labels = sm.fit_resample(train_data.reshape(-1, IMG_SIZE * IMG_SIZE * 3), train_labels)

print(train_data.shape, train_labels.shape)
# Out:
# (12800, 49152) (12800, 4)

# %%
train_data = train_data.reshape(-1, IMG_SIZE, IMG_SIZE, 3)
print(train_data.shape, train_labels.shape)
# Out:
# (12800, 128, 128, 3) (12800, 4)

# %%
train_data, test_data, train_labels,test_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

train_data, val_data, train_labels,val_labels = train_test_split(train_data, train_labels, test_size = 0.2, random_state=42)

# %%
# Defining convolutional blocks
def conv_block(filters, act='relu'):
    
    block = Sequential()
    block.add(Conv2D(filters, 3, activation=act, padding='same'))
    block.add(Conv2D(filters, 3, activation=act, padding='same'))
    block.add(BatchNormalization())
    block.add(MaxPool2D())
    
    return block

# %%
# defining dense blocks
def dense_block(units, dropout_rate, act='relu'):
    block = Sequential()
    block.add(Dense(units, activation=act))
    block.add(BatchNormalization())
    block.add(Dropout(dropout_rate))
    
    return block

# %%
IMAGE_SIZE = [128,128]
act = 'relu'

# %%
model = Sequential([
        Input(shape=(*IMAGE_SIZE, 3)),
        Conv2D(16, 3, activation=act, padding='same'),
        Conv2D(16, 3, activation=act, padding='same'),
        MaxPool2D(),
        conv_block(32),
        conv_block(64),
        conv_block(128),
        Dropout(0.2),
        conv_block(256),
        Dropout(0.2),
        Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        Dense(4, activation='softmax')        
    ], name = "cnn_model")

# %%
METRICS = [tf.keras.metrics.CategoricalAccuracy(name='acc'),
           tf.keras.metrics.AUC(name='auc'), 
           tfa.metrics.F1Score(num_classes=4)]

model.compile(optimizer='adam',
              loss=tf.losses.CategoricalCrossentropy(),
              metrics=METRICS)

model.summary()
# Out:
# Model: "cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 16)      2320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  sequential (Sequential)     (None, 32, 32, 32)        14016
#
#  sequential_1 (Sequential)   (None, 16, 16, 64)        55680
#
#  sequential_2 (Sequential)   (None, 8, 8, 128)         221952
#
#  dropout (Dropout)           (None, 8, 8, 128)         0
#
#  sequential_3 (Sequential)   (None, 4, 4, 256)         886272
#
#  dropout_1 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  sequential_4 (Sequential)   (None, 512)               2099712
#
#  sequential_5 (Sequential)   (None, 128)               66176
#
#  sequential_6 (Sequential)   (None, 64)                8512
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 3,355,348
# Trainable params: 3,352,980
# Non-trainable params: 2,368
# _________________________________________________________________

# %%
plot_model(model)

# %%
CALLBACKS = [
    EarlyStopping(monitor='accuracy', min_delta=0.01, patience=5, mode='max')
]

# %%
EPOCHS = 50

history = model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=EPOCHS,callbacks=CALLBACKS)
# Out:
# Epoch 1/50
# 2023-04-23 09:39:18.538367: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape incnn_model/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 256/256 [==============================] - 28s 41ms/step - loss: 1.6041 - acc: 0.3097 - auc: 0.5745 - f1_score: 0.3079 - val_loss: 6.3972 - val_acc: 0.2402 - val_auc: 0.5059 - val_f1_score: 0.0969
# Epoch 2/50
# 256/256 [==============================] - 9s 36ms/step - loss: 1.0977 - acc: 0.5010 - auc: 0.7804 - f1_score: 0.4908 - val_loss: 8.9605 - val_acc: 0.2402 - val_auc: 0.5008 - val_f1_score: 0.0969
# Epoch 3/50
# 256/256 [==============================] - 9s 35ms/step - loss: 0.8162 - acc: 0.6232 - auc: 0.8774 - f1_score: 0.6141 - val_loss: 1.0547 - val_acc: 0.4985 - val_auc: 0.8006 - val_f1_score: 0.4154
# Epoch 4/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.7257 - acc: 0.6653 - auc: 0.9022 - f1_score: 0.6596 - val_loss: 4.3716 - val_acc: 0.2612 - val_auc: 0.5426 - val_f1_score: 0.1628
# Epoch 5/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.6637 - acc: 0.6957 - auc: 0.9182 - f1_score: 0.6933 - val_loss: 0.6309 - val_acc: 0.7212 - val_auc: 0.9285 - val_f1_score: 0.7058
# Epoch 6/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.6284 - acc: 0.7134 - auc: 0.9273 - f1_score: 0.7126 - val_loss: 2.0877 - val_acc: 0.3403 - val_auc: 0.6218 - val_f1_score: 0.2986
# Epoch 7/50
# 256/256 [==============================] - 9s 35ms/step - loss: 0.5583 - acc: 0.7484 - auc: 0.9424 - f1_score: 0.7479 - val_loss: 1.5254 - val_acc: 0.3887 - val_auc: 0.7191 - val_f1_score: 0.3534
# Epoch 8/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.5378 - acc: 0.7618 - auc: 0.9468 - f1_score: 0.7614 - val_loss: 1.2844 - val_acc: 0.5293 - val_auc: 0.8674 - val_f1_score: 0.4339
# Epoch 9/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.4617 - acc: 0.7935 - auc: 0.9600 - f1_score: 0.7927 - val_loss: 0.5460 - val_acc: 0.7524 - val_auc: 0.9449 - val_f1_score: 0.7519
# Epoch 10/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.4563 - acc: 0.8008 - auc: 0.9612 - f1_score: 0.8003 - val_loss: 1.1788 - val_acc: 0.6240 - val_auc: 0.8823 - val_f1_score: 0.5988
# Epoch 11/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.4191 - acc: 0.8208 - auc: 0.9674 - f1_score: 0.8204 - val_loss: 0.4691 - val_acc: 0.7861 - val_auc: 0.9611 - val_f1_score: 0.7688
# Epoch 12/50
# 256/256 [==============================] - 10s 37ms/step - loss: 0.3803 - acc: 0.8361 - auc: 0.9728 - f1_score: 0.8359 - val_loss: 0.7149 - val_acc: 0.7178 - val_auc: 0.9203 - val_f1_score: 0.7156
# Epoch 13/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0
50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0517 - acc: 0.9840 - auc: 0.9991 - f1_score: 0.9840 - val_loss: 0.2590 - val_acc: 0.9277 - val_auc: 0.9858 - val_f1_score: 0.9270
# Epoch 44/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0506 - acc: 0.9846 - auc: 0.9982 - f1_score: 0.9846 - val_loss: 0.3007 - val_acc: 0.9253 - val_auc: 0.9848 - val_f1_score: 0.9249
# Epoch 45/50
# 256/256 [==============================] - 9s 36ms/step - loss: 0.0536 - acc: 0.9841 - auc: 0.9986 - f1_score: 0.9841 - val_loss: 0.2652 - val_acc: 0.9258 - val_auc: 0.9862 - val_f1_score: 0.9260
# Epoch 46/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0365 - acc: 0.9884 - auc: 0.9993 - f1_score: 0.9884 - val_loss: 0.3336 - val_acc: 0.9160 - val_auc: 0.9818 - val_f1_score: 0.9157
# Epoch 47/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0413 - acc: 0.9865 - auc: 0.9993 - f1_score: 0.9864 - val_loss: 0.3346 - val_acc: 0.9180 - val_auc: 0.9807 - val_f1_score: 0.9160
# Epoch 48/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0465 - acc: 0.9857 - auc: 0.9988 - f1_score: 0.9857 - val_loss: 0.4178 - val_acc: 0.8960 - val_auc: 0.9734 - val_f1_score: 0.8967
# Epoch 49/50
# 256/256 [==============================] - 9s 37ms/step - loss: 0.0284 - acc: 0.9902 - auc: 0.9996 - f1_score: 0.9902 - val_loss: 0.3127 - val_acc: 0.9390 - val_auc: 0.9813 - val_f1_score: 0.9392
# Epoch 50/50
# 256/256 [==============================] - 10s 37ms/step - loss: 0.0353 - acc: 0.9893 - auc: 0.9993 - f1_score: 0.9893 - val_loss: 0.3399 - val_acc: 0.9219 - val_auc: 0.9795 - val_f1_score: 0.9226

# %%
test_scores = model.evaluate(test_data, test_labels)
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
# Out:
# 80/80 [==============================] - 1s 11ms/step - loss: 0.3767 - acc: 0.9047 - auc: 0.9761 - f1_score: 0.9063
# Testing Accuracy: 90.47%

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    ax[i].plot(history.history[metric])
    ax[i].plot(history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])

# %% [markdown]
# ## Transfer learning with Inceptionv3 model

# %%
inception = InceptionV3(input_shape=(128,128,3),include_top=False,weights ='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 2s 0us/step

# %%
for layer in inception.layers:
    layer.trainable = False

# %%
inception_model = Sequential([
        inception,
        Dropout(0.5),
        GlobalAveragePooling2D(),
        Flatten(),
        BatchNormalization(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(64, activation='relu'),
        Dropout(0.5),
        BatchNormalization(),
        Dense(4, activation='softmax')        
    ], name = "inception_cnn_model")

# %%
inception_model.compile(optimizer='rmsprop',
                              loss=tf.losses.CategoricalCrossentropy(),
                              metrics=METRICS)

inception_model.summary()
# Out:
# Model: "inception_cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2, 2, 2048)        21802784
#
#  dropout_5 (Dropout)         (None, 2, 2, 2048)        0
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  batch_normalization_101 (Ba  (None, 2048)             8192
#  tchNormalization)
#
#  dense_4 (Dense)             (None, 512)               1049088
#
#  batch_normalization_102 (Ba  (None, 512)              2048
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  batch_normalization_103 (Ba  (None, 256)              1024
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  batch_normalization_104 (Ba  (None, 128)              512
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  batch_normalization_105 (Ba  (None, 64)               256
#  tchNormalization)
#
#  dense_8 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 23,036,644
# Trainable params: 1,227,844
# Non-trainable params: 21,808,800
# _________________________________________________________________

# %%
plot_model(inception_model)

# %%
INCEPT_CALLBACKS = [
    ModelCheckpoint(filepath='incpt_model_checkpoint.h5', save_best_only=True),
    EarlyStopping(patience=3)
]

# %%
incept_history = inception_model.fit(train_data, train_labels, validation_data=(val_data, val_labels), epochs=50,callbacks= INCEPT_CALLBACKS)
# Out:
# Epoch 1/50
# 2023-04-23 09:47:48.049738: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ininception_cnn_model/dropout_5/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 256/256 [==============================] - 21s 51ms/step - loss: 1.4530 - acc: 0.5150 - auc: 0.7796 - f1_score: 0.5131 - val_loss: 0.8447 - val_acc: 0.6030 - val_auc: 0.8668 - val_f1_score: 0.6010
# Epoch 2/50
# 256/256 [==============================] - 11s 43ms/step - loss: 0.9979 - acc: 0.5411 - auc: 0.8197 - f1_score: 0.5354 - val_loss: 0.7435 - val_acc: 0.6450 - val_auc: 0.8942 - val_f1_score: 0.6376
# Epoch 3/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.8578 - acc: 0.6039 - auc: 0.8650 - f1_score: 0.5974 - val_loss: 0.6933 - val_acc: 0.6753 - val_auc: 0.9091 - val_f1_score: 0.6660
# Epoch 4/50
# 256/256 [==============================] - 11s 42ms/step - loss: 0.7847 - acc: 0.6433 - auc: 0.8872 - f1_score: 0.6359 - val_loss: 0.6572 - val_acc: 0.6899 - val_auc: 0.9185 - val_f1_score: 0.6831
# Epoch 5/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.7512 - acc: 0.6625 - auc: 0.8977 - f1_score: 0.6584 - val_loss: 0.6387 - val_acc: 0.6958 - val_auc: 0.9218 - val_f1_score: 0.6841
# Epoch 6/50
# 256/256 [==============================] - 11s 42ms/step - loss: 0.7162 - acc: 0.6826 - auc: 0.9070 - f1_score: 0.6808 - val_loss: 0.6077 - val_acc: 0.7148 - val_auc: 0.9318 - val_f1_score: 0.7128
# Epoch 7/50
# 256/256 [==============================] - 10s 38ms/step - loss: 0.6898 - acc: 0.6970 - auc: 0.9143 - f1_score: 0.6963 - val_loss: 0.5572 - val_acc: 0.7480 - val_auc: 0.9437 - val_f1_score: 0.7452
# Epoch 8/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.6670 - acc: 0.7087 - auc: 0.9195 - f1_score: 0.7080 - val_loss: 0.5603 - val_acc: 0.7466 - val_auc: 0.9421 - val_f1_score: 0.7483
# Epoch 9/50
# 256/256 [==============================] - 11s 41ms/step - loss: 0.6445 - acc: 0.7272 - auc: 0.9261 - f1_score: 0.7264 - val_loss: 0.5350 - val_acc: 0.7524 - val_auc: 0.9473 - val_f1_score: 0.7513
# Epoch 10/50
# 256/256 [==============================] - 11s 42ms/step - loss: 0.6252 - acc: 0.7329 - auc: 0.9305 - f1_score: 0.7315 - val_loss: 0.4992 - val_acc: 0.7856 - val_auc: 0.9556 - val_f1_score: 0.7823
# Epoch 11/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.6015 - acc: 0.7524 - auc: 0.9365 - f1_score: 0.7509 - val_loss: 0.4776 - val_acc: 0.7827 - val_auc: 0.9585 - val_f1_score: 0.7813
# Epoch 12/50
# 256/256 [==============================] - 11s 42ms/step - loss: 0.5863 - acc: 0.7614 - auc: 0.9395 - f1_score: 0.7602 - val_loss: 0.4769 - val_acc: 0.7949 - val_auc: 0.9588 - val_f1_score: 0.7906
# Epoch 13/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.5543 - acc: 0.7698 - auc: 0.9456 - f1_score: 0.7682 - val_loss: 0.4592 - val_acc: 0.7935 - val_auc: 0.9617 - val_f1_score: 0.7917
# Epoch 14/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.5393 - acc: 0.7778 - auc: 0.9485 - f1_score: 0.7766 - val_loss: 0.4383 - val_acc: 0.8218 - val_auc: 0.9659 - val_f1_score: 0.8202
# Epoch 15/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.5240 - acc: 0.7889 - auc: 0.9515 - f1_score: 0.7876 - val_loss: 0.4431 - val_acc: 0.8022 - val_auc: 0.9643 - val_f1_score: 0.8004
# Epoch 16/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.5083 - acc: 0.7961 - auc: 0.9543 - f1_score: 0.7947 - val_loss: 0.4496 - val_acc: 0.8047 - val_auc: 0.9629 - val_f1_score: 0.8023
# Epoch 17/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.5080 - acc: 0.8002 - auc: 0.9547 - f1_score: 0.7990 - val_loss: 0.4161 - val_acc: 0.8271 - val_auc: 0.9686 - val_f1_score: 0.8244
# Epoch 18/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.4987 - acc: 0.8032 - auc: 0.9564 - f1_score: 0.8023 - val_loss: 0.4140 - val_acc: 0.8252 - val_auc: 0.9687 - val_f1_score: 0.8243
# Epoch 19/50
# 256/256 [==============================] - 10s 38ms/step - loss: 0.4836 - acc: 0.8137 - auc: 0.9587 - f1_score: 0.8130 - val_loss: 0.4036 - val_acc: 0.8345 - val_auc: 0.9705 - val_f1_score: 0.8322
# Epoch 20/50
# 256/256 [==============================] - 11s 43ms/step - loss: 0.4810 - acc: 0.8154 - auc: 0.9594 - f1_score: 0.8143 - val_loss: 0.3909 - val_acc: 0.8340 - val_auc: 0.9723 - val_f1_score: 0.8315
# Epoch 21/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.4536 - acc: 0.8217 - auc: 0.9638 - f1_score: 0.8209 - val_loss: 0.3955 - val_acc: 0.8242 - val_auc: 0.9712 - val_f1_score: 0.8220
# Epoch 22/50
# 256/256 [==============================] - 11s 42ms/step - loss: 0.4520 - acc: 0.8274 - auc: 0.9641 - f1_score: 0.8264 - val_loss: 0.3799 - val_acc: 0.8379 - val_auc: 0.9734 - val_f1_score: 0.8368
# Epoch 23/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.4297 - acc: 0.8354 - auc: 0.9671 - f1_score: 0.8351 - val_loss: 0.3692 - val_acc: 0.8418 - val_auc: 0.9751 - val_f1_score: 0.8405
# Epoch 24/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.4263 - acc: 0.8346 - auc: 0.9675 - f1_score: 0.8339 - val_loss: 0.3692 - val_acc: 0.8359 - val_auc: 0.9746 - val_f1_score: 0.8352
# Epoch 25/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.4107 - acc: 0.8440 - auc: 0.9697 - f1_score: 0.8432 - val_loss: 0.3734 - val_acc: 0.8359 - val_auc: 0.9742 - val_f1_score: 0.8344
# Epoch 26/50
# 256/256 [==============================] - 10s 38ms/step - loss: 0.4184 - acc: 0.8430 - auc: 0.9687 - f1_score: 0.8421 - val_loss: 0.3597 - val_acc: 0.8452 - val_auc: 0.9762 - val_f1_score: 0.8447
# Epoch 27/50
# 256/256 [==============================] - 10s 41ms/step - loss: 0.4039 - acc: 0.8477 - auc: 0.9706 - f1_score: 0.8472 - val_loss: 0.3657 - val_acc: 0.8486 - val_auc: 0.9756 - val_f1_score: 0.8454
# Epoch 28/50
# 256/256 [==============================] - 10s 38ms/step - loss: 0.3782 - acc: 0.8606 - auc: 0.9740 - f1_score: 0.8599 - val_loss: 0.3523 - val_acc: 0.8525 - val_auc: 0.9775 - val_f1_score: 0.8508
# Epoch 29/50
# 256/256 [==============================] - 11s 42ms/step - loss: 0.3680 - acc: 0.8638 - auc: 0.9754 - f1_score: 0.8632 - val_loss: 0.3514 - val_acc: 0.8535 - val_auc: 0.9772 - val_f1_score: 0.8521
# Epoch 30/50
# 256/256 [==============================] - 11s 44ms/step - loss: 0.3706 - acc: 0.8638 - auc: 0.9750 - f1_score: 0.8632 - val_loss: 0.3498 - val_acc: 0.8569 - val_auc: 0.9775 - val_f1_score: 0.8559
# Epoch 31/50
# 256/256 [==============================] - 10s 39ms/step - loss: 0.3797 - acc: 0.8582 - auc: 0.9738 - f1_score: 0.8578 - val_loss: 0.3371 - val_acc: 0.8608 - val_auc: 0.9792 - val_f1_score: 0.8598
# Epoch 32/50
# 256/256 [==============================] - 10s 37ms/step - loss: 0.3685 - acc: 0.8644 - auc: 0.9750 - f1_score: 0.8639 - val_loss: 0.3418 - val_acc: 0.8496 - val_auc: 0.9784 - val_f1_score: 0.8474
# Epoch 33/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.3680 - acc: 0.8647 - auc: 0.9756 - f1_score: 0.8644 - val_loss: 0.3392 - val_acc: 0.8618 - val_auc: 0.9789 - val_f1_score: 0.8603
# Epoch 34/50
# 256/256 [==============================] - 10s 40ms/step - loss: 0.3662 - acc: 0.8660 - auc: 0.9756 - f1_score: 0.8654 - val_loss: 0.3393 - val_acc: 0.8501 - val_auc: 0.9787 - val_f1_score: 0.8485

# %%
incept_test_scores = inception_model.evaluate(test_data, test_labels)
print("Testing Accuracy: %.2f%%"%(incept_test_scores[1] * 100))
# Out:
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3391 - acc: 0.8691 - auc: 0.9790 - f1_score: 0.8688
# Testing Accuracy: 86.91%

# %%
#Plotting the trend of the metrics during training

fig, ax = plt.subplots(1, 3, figsize = (30, 5))
ax = ax.ravel()

for i, metric in enumerate(["acc", "auc", "loss"]):
    ax[i].plot(incept_history.history[metric])
    ax[i].plot(incept_history.history["val_" + metric])
    ax[i].set_title("Model {}".format(metric))
    ax[i].set_xlabel("Epochs")
    ax[i].set_ylabel(metric)
    ax[i].legend(["train", "val"])
